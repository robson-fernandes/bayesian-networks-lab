# %%
import pandas as pd
import numpy as np
import pyflux as pf
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
print(plt.style.available)
# Out:
# ['_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2']

# %%
data = pd.read_csv('data/data-sales.csv', delimiter=';')
#data['mes'] = pd.to_datetime(data['mes'])
#data.index = data['mes'].values

# %%
# The adjusted close accounts for stock splits, so that is what we should graph
plt.plot(data.index, data['grupoBebida'])
plt.title('Grupo de Bebida')
plt.ylabel('Price ($)');
plt.show()
plt.plot(data.index, data['grupoSanduiche'], 'r')
plt.title('Grupo Sanduiche')
plt.ylabel('Price ($)');
plt.show();

# %%
df_train = data.iloc[1:84,]
df_test = data.iloc[85:90,]

# %%
plt.figure(figsize=(10, 8))
plt.plot(data.index, data['grupoBebida'], 'b-', label = 'Grupo de Bebidas')
plt.plot(data.index, data['grupoSanduiche'], 'r-', label = 'Grupo de Sanduiches')
plt.xlabel('Date'); plt.ylabel('Quantidade de Produtos por Grupo Vendidos'); plt.title('Grupos de Produtos de Vendas')
plt.legend();
