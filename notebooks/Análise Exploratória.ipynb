# %%
dados.vendas <- read.csv("data/food-sp.csv", header=TRUE)

# %%
dados.vendas = as.data.frame(dados.vendas)

# %%
dados.vendas[is.na(dados.vendas)] <- 0
dados.vendas$PROJETO.CAFÉ[dados.vendas$PROJETO.CAFÉ == 0] <- mean(dados.vendas$PROJETO.CAFÉ)
dados.vendas$BRINDE[dados.vendas$BRINDE == 0] <- mean(dados.vendas$BRINDE)

# %%
dados.vendas = dados.vendas[, c('DATA',
                                'GELADO.E.MILK.SHAKE', 
                                'SANDUICHE', 
                                'BEBIDA', 
                                'ACOMPANHAMENTO',
                                'ADICIONAL', 
                                'PROJETO.CAFÉ',
                                'BRINDE',
                                'PRATO',
                                'VENDA'
                               )]

# %%
colnames(dados.vendas)[colnames(dados.vendas) == 'PROJETO.CAFÉ'] <- 'Café'
colnames(dados.vendas)[colnames(dados.vendas) == 'GELADO.E.MILK.SHAKE'] <- 'Milkshake'
colnames(dados.vendas)[colnames(dados.vendas) == 'SANDUICHE'] <- 'Sanduíche'
colnames(dados.vendas)[colnames(dados.vendas) == 'BEBIDA'] <- 'Bebida'
colnames(dados.vendas)[colnames(dados.vendas) == 'ACOMPANHAMENTO'] <- 'Acompanhamento'
colnames(dados.vendas)[colnames(dados.vendas) == 'ADICIONAL'] <- 'Adicional'
colnames(dados.vendas)[colnames(dados.vendas) == 'BRINDE'] <- 'Brinde'
colnames(dados.vendas)[colnames(dados.vendas) == 'PRATO'] <- 'Prato'
colnames(dados.vendas)[colnames(dados.vendas) == 'VENDA'] <- 'Venda'

# %%
dados.vendas$DATA =   as.Date(dados.vendas$DATA)

# %%
df.2010 = dados.vendas[(dados.vendas$DATA >= '2010-01-01') & (dados.vendas$DATA < '2011-01-01'),]
df.2011 = dados.vendas[(dados.vendas$DATA >= '2011-01-01') & (dados.vendas$DATA < '2012-01-01'),]
df.2012 = dados.vendas[(dados.vendas$DATA >= '2012-01-01') & (dados.vendas$DATA < '2013-01-01'),]
df.2013 = dados.vendas[(dados.vendas$DATA >= '2013-01-01') & (dados.vendas$DATA < '2014-01-01'),]
df.2014 = dados.vendas[(dados.vendas$DATA >= '2014-01-01') & (dados.vendas$DATA < '2015-01-01'),]
df.2015 = dados.vendas[(dados.vendas$DATA >= '2015-01-01') & (dados.vendas$DATA < '2016-01-01'),]
df.2016 = dados.vendas[(dados.vendas$DATA >= '2016-01-01') & (dados.vendas$DATA < '2017-01-01'),]
df.2017 = dados.vendas[(dados.vendas$DATA >= '2017-01-01') & (dados.vendas$DATA < '2018-01-01'),]

# %%
library(ggplot2)
library(gridExtra)
theme_set(theme_minimal())

# %%
label = "Acompanhamento"
y_label = paste("Venda de", label, "(R$)", sep = " ")

smooth = stat_smooth(colour="red")
smooth_true = TRUE
color_variable = "lightblue"
fill_variable = "lightblue"

p2010 = ggplot(df.2010, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2011 = ggplot(df.2011, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label) 
  

p2012 = ggplot(df.2012, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2013 = ggplot(df.2013, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)


p2014 = ggplot(df.2014, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2015 = ggplot(df.2015, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2016 = ggplot(df.2016, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2017 = ggplot(df.2017, aes(x = DATA, y = Acompanhamento)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

if (smooth_true){
    p2010 = p2010 + smooth
    p2011 = p2011 + smooth
    p2012 = p2012 + smooth
    p2013 = p2013 + smooth
    p2014 = p2014 + smooth
    p2015 = p2015 + smooth
    p2016 = p2016 + smooth
    p2017 = p2017 + smooth
}

grid.arrange(p2010, p2011, p2012, p2013, nrow = 2)
grid.arrange(p2014, p2015, p2016, p2017, nrow = 2)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title
# plot without title

# %%
label = "Bebida"
y_label = paste("Venda de", label, "(R$)", sep = " ")

smooth = stat_smooth(colour="magenta2")
smooth_true = TRUE
color_variable = "lightblue"
fill_variable = "lightblue"

p2010 = ggplot(df.2010, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2011 = ggplot(df.2011, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label) 
  

p2012 = ggplot(df.2012, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2013 = ggplot(df.2013, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)


p2014 = ggplot(df.2014, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2015 = ggplot(df.2015, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2016 = ggplot(df.2016, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2017 = ggplot(df.2017, aes(x = DATA, y = Bebida)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

if (smooth_true){
    p2010 = p2010 + smooth
    p2011 = p2011 + smooth
    p2012 = p2012 + smooth
    p2013 = p2013 + smooth
    p2014 = p2014 + smooth
    p2015 = p2015 + smooth
    p2016 = p2016 + smooth
    p2017 = p2017 + smooth
}

grid.arrange(p2010, p2011, p2012, p2013, nrow = 2)
grid.arrange(p2014, p2015, p2016, p2017, nrow = 2)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title
# plot without title

# %%
label = "Sanduíche"
y_label = paste("Venda de", label, "(R$)", sep = " ")

smooth = stat_smooth(colour="orange")
smooth_true = TRUE
color_variable = "lightblue"
fill_variable = "lightblue"

p2010 = ggplot(df.2010, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2011 = ggplot(df.2011, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label) 
  

p2012 = ggplot(df.2012, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2013 = ggplot(df.2013, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)


p2014 = ggplot(df.2014, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2015 = ggplot(df.2015, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2016 = ggplot(df.2016, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2017 = ggplot(df.2017, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

if (smooth_true){
    p2010 = p2010 + smooth
    p2011 = p2011 + smooth
    p2012 = p2012 + smooth
    p2013 = p2013 + smooth
    p2014 = p2014 + smooth
    p2015 = p2015 + smooth
    p2016 = p2016 + smooth
    p2017 = p2017 + smooth
}

grid.arrange(p2010, p2011, p2012, p2013, nrow = 2)
grid.arrange(p2014, p2015, p2016, p2017, nrow = 2)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title
# plot without title

# %%
label = "Milkshake"
y_label = paste("Venda de", label, "(R$)", sep = " ")

smooth = stat_smooth(colour="green3")
smooth_true = TRUE
color_variable = "lightblue"
fill_variable = "lightblue"

p2010 = ggplot(df.2010, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2011 = ggplot(df.2011, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label) 
  

p2012 = ggplot(df.2012, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2013 = ggplot(df.2013, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)


p2014 = ggplot(df.2014, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2015 = ggplot(df.2015, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2016 = ggplot(df.2016, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

p2017 = ggplot(df.2017, aes(x = DATA, y = Milkshake)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)

if (smooth_true){
    p2010 = p2010 + smooth
    p2011 = p2011 + smooth
    p2012 = p2012 + smooth
    p2013 = p2013 + smooth
    p2014 = p2014 + smooth
    p2015 = p2015 + smooth
    p2016 = p2016 + smooth
    p2017 = p2017 + smooth
}

grid.arrange(p2010, p2011, p2012, p2013, nrow = 2)
grid.arrange(p2014, p2015, p2016, p2017, nrow = 2)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title
# plot without title

# %% [markdown]
# # Análise Sazonal - Sanduíche

# %%
library(forecast)
options(warn=-1)

ts.vendas <- ts(dados.vendas$Sanduíche, start=c(2010, 1), end=c(2017, 12), frequency=12) 

ts.vendas.stl <- stl(ts.vendas,"periodic") # decompose the TS
ts.vendas.sa <- seasadj(ts.vendas.stl)  # de-seasonalize

label = "Sanduíche"
y_label = paste("Vendas de", label, "(R$)", sep = " ")
ggplot(dados.vendas, aes(x = DATA, y = Sanduíche)) + 
  geom_area(color = color_variable,fill = fill_variable, alpha = 0.5, position = position_dodge(0.8)) +
           xlab("Período") + ylab(y_label)


ggseasonplot(ts.vendas.sa, 12, 
             year.labels=TRUE, 
             season.labels = c("Jan", 
                               "Fev", 
                               "Mar", 
                               "Abr", 
                               "Mai", 
                               "Jun", 
                               "Jul", 
                               "Ago", 
                               "Set", 
                               "Out", 
                               "Nov", 
                               "Dez")) + xlab("Período") + ylab(y_label) + ggtitle("")
# Out:
# plot without title
# plot without title

# %%
library(tseries)
adf.test(ts.vendas) # p-value < 0.05 indicates the TS is stationary
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  ts.vendas
# Dickey-Fuller = -2.6516, Lag order = 4, p-value = 0.3072
# alternative hypothesis: stationary
