# %% [markdown]
# <br>
# <hr>
#
# <div style="text-align: justify;">
# <br>
# <center><div><b style="font-size:21px;">Mestrado profissional em Matemática, Estatística e Computação Aplicadas à Indústria</b></div></center>
# <center><div><b style="font-size:22px;color:#72849d">Redes Bayesianas Gaussianas aplicada à predição de vendas em uma grande rede de fast-food brasileira</b></div></center>
# <br>
# <div style="text-align: justify;">
# Resultados apresentados ao Instituto de Ciências Matemáticas e de Computação - ICMC-USP, como parte dos requisitos para obtenção do título de mestre - Mestrado profissional em Matemática, Estatística e Computação Aplicadas à Indústria, sob orientação do <a href="http://conteudo.icmc.usp.br/pessoas/alneu/" target="_blank"> Prof. Dr. Alneu de Andrade Lopes</a> e Co-Orientação <a href="https://scholar.google.com/citations?user=tuOaq-4AAAAJ&hl=pt-BR" target="_blank">Dr. Brett Drury.</a>
# </div>
# <br>
# <hr>
# <center><div><b style="font-size:22px;">Previsão de Vendas - Grupo de Acompanhamento - SP</b></div></center>
# <hr>

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from pyramid.arima import auto_arima

plt.style.use('seaborn')

# %%
data = pd.read_excel('data/food-sp.xlsx')

# %%
data.columns.values
# Out:
# array(['UF', 'DATA', 'VENDA', 'ADICIONAL', 'BRINDE', 'MOLHO FESTIVAL',
#        'CHOPP COM UNIDADE EM LITRO', 'BEBIDA COM UNIDADE EM LITRO',
#        'BEX SALADAS', 'DOCE E TORTA', 'BEBIDA', 'MOLHO',
#        'GELADO E MILK SHAKE', 'ITENS DE COMPOSIÇÃO', 'BEX SNACKS',
#        'BEX DOCES', 'BEX SANDUICHES E MOLHOS', 'SACHET MOLHO PINCANHA',
#        'BEX GELADOS E MILKSHAKES', 'BEX CAFE', 'PROJETO CAFÉ',
#        'PROJETO CHOPP', 'PRATO', 'BEX BEBIDAS', 'LANCHE FRANQUEADO',
#        'ACOMPANHAMENTO', 'SANDUICHE', 'LINHA ORIGINAL', 'OUTROS',
#        'CALDA BOBS TOP', 'REFEICAO COLABORADORES'], dtype=object)

# %%
variavel = 'ACOMPANHAMENTO'

# %%
data.index = data['DATA']

# %%
df_train = data.iloc[1:84,]
df_test = data.iloc[84:96,]

# %%
plt.figure(figsize=(15,5))
plt.plot(list(range(1,84)), df_train[variavel])
plt.ylabel('Grupo de '+ variavel.title())
plt.title('Série Temporal - Grupo de '+ variavel.title())
plt.show()

# %%
df_train[variavel+'_box'], lmbda = stats.boxcox(df_train[variavel])

# %%
model = auto_arima(df_train[variavel+'_box'], 
                    n_fits=12,
                    start_p=0, 
                    start_q=0, 
                    max_p=5, 
                    max_q=5, 
                    m=35,
                    start_P=0, 
                    d=1, 
                    D=1, 
                    trace=True,
                    stationary=False,
                    error_action='ignore',  # don't want to know if an order does not work
                    suppress_warnings=True,  # don't want convergence warnings
                    stepwise=True)  # set to stepwise
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 0, 35); AIC=1540.522, BIC=1557.454, Fit time=2.949 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 0, 35); AIC=1545.854, BIC=1560.367, Fit time=1.542 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 1, 0, 35); AIC=1535.016, BIC=1554.367, Fit time=3.273 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 1, 0, 35); AIC=1523.102, BIC=1544.872, Fit time=3.189 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(0, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 1, 0, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 1, 1, 35); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(0, 1, 0, 35); AIC=1524.479, BIC=1548.667, Fit time=3.629 seconds
# Total fit time: 14.673 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   83
# Model:             SARIMAX(4, 1, 3)x(0, 1, 0, 35)   Log Likelihood                -752.551
# Date:                            Sun, 11 Mar 2018   AIC                           1523.102
# Time:                                    00:09:27   BIC                           1544.872
# Sample:                                         0   HQIC                          1531.848
#                                              - 83
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -7.294e+05   3.09e-07  -2.36e+12      0.000   -7.29e+05   -7.29e+05
# ar.L1         -1.6002      0.274     -5.838      0.000      -2.137      -1.063
# ar.L2         -1.3120      0.390     -3.363      0.001      -2.077      -0.547
# ar.L3         -0.7877      0.490     -1.609      0.108      -1.747       0.172
# ar.L4         -0.5293      0.342     -1.546      0.122      -1.200       0.142
# ma.L1          0.9223      0.262      3.524      0.000       0.409       1.435
# ma.L2         -0.2202      0.472     -0.467      0.641      -1.145       0.704
# ma.L3         -0.5350      0.388     -1.379      0.168      -1.296       0.225
# sigma2      6.352e+12   4.81e-14   1.32e+26      0.000    6.35e+12    6.35e+12
# ===================================================================================
# Ljung-Box (Q):                       49.01   Jarque-Bera (JB):                 1.47
# Prob(Q):                              0.16   Prob(JB):                         0.48
# Heteroskedasticity (H):               2.14   Skew:                             0.43
# Prob(H) (two-sided):                  0.14   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.62e+42. Standard errors may be unstable.
# """

# %%
forecast = model.predict(n_periods=12)
forecast
# Out:
# array([ 6000188.54180704,  7947131.93628023,  9857263.06568808,
#         8648044.19358264, 11814685.85422025,  5692949.79132945,
#         9028258.39538499,  7143788.79519844,  6779648.00468242,
#        12126913.61884362, 10993385.61305863, 10122525.79168172])

# %%
len(df_test[variavel].values)
# Out:
# 12

# %%
len(forecast)
# Out:
# 12

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
    if lmbda == 0:
        return(np.exp(y))
    else:
        return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
y_pred = invboxcox(forecast,lmbda)
y_true = df_test[variavel].values

# %% [markdown]
# <h1>Acurácia</h1>

# %%
acuracia = round(100 - mean_absolute_percentage_error(y_true , y_pred),0)
acuracia
# Out:
# 81.0

# %%
plt.figure(figsize=(15,6))
plt.plot(list(range(1,13)), y_pred, '--', label='Previsão de Vendas : '+ variavel.title() ,color='r')
plt.legend()
plt.plot(list(range(1,13)), y_true, label='Vendas : '+ variavel.title())
plt.legend()
plt.ylabel('Grupo de '+ variavel.title())
plt.title('Série Temporal - Grupo de '+ variavel.title())
plt.show()
