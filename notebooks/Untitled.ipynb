# %% [markdown]
# # Análise de Normalidade

# %%
install.packages("Johnson")
# Out:
# The downloaded binary packages are in
# 	/var/folders/4c/dsd17b2x1993_dmc06_2t81m0000gn/T//RtmpKQsRCw/downloaded_packages

# %%
dados.vendas <- read.csv("data/food-rj.csv", header=TRUE)

# %%
x = dados.vendas[,c("GELADO.E.MILK.SHAKE")]
x = log(x)

# %%
 #Plotting transformed data
hist(x, breaks = 25, col = rgb(0.9, 0.1, 0.1, 0.5))
qqnorm(x)
qqline(x, col = "red")
# Out:
# Plot with title “Histogram of x”
# Plot with title “Normal Q-Q Plot”

# %%
box.cox(x,2)
# Out:
# Error in box.cox(x, 2): não foi possível encontrar a função "box.cox"
# Traceback:
